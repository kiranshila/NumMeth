# %% [markdown]
# # Week 5 - Boundary Value Problems in 2D
# ## Kiran Shila - U54532811

# %%
using LinearAlgebra
using SparseArrays
using Plots
using BenchmarkTools
using Interpolations
using Statistics

# %% [markdown]
# ## Formulation
# Alright, let's form some finite differences.
#
# ### Problem to Solve
# $-\nabla^2\varphi(x,y) = s(x,y)$
#
# Then to the differential equation for this coordinate system
#
# $-\frac{\delta^2\varphi}{\delta x^2}-\frac{\delta^2\varphi}{\delta y^2} = s(x,y)$
#
# ### Finite Difference Formulation
# We will use the central finite difference to formulate the A matrix
#
# $-\frac{\varphi(x_{i-1},y_j) - 2\varphi(x_i,y_j) + \varphi(x_{i+1},y_j)}{\Delta x^2}-\frac{\varphi(x_{i},y_{j-1}) - 2\varphi(x_i,y_j) + \varphi(x_i,y_{j+1})}{\Delta y^2} = s(x_i,y_j)$
#
# ### Finite Difference as a Matrix
# So as a matrix:
#
# $\textbf{D}_x^{(2)} = \frac{1}{\Delta_x^2}
# \begin{bmatrix}
#     -2 & 1 & 0 & \dots  & 0 \\
#     1 & -2 & 1 & \dots  & 0 \\
#     \vdots & \vdots & \vdots & \ddots & \vdots \\
#     0 & 0 & 0 & \dots  & -2
# \end{bmatrix}
# $
#
# But, we need to correct some terms as we are in 2D.
#
# If we assume the problem space is L x H (columns,rows) , we can form the source vector as so
#
# $
# \begin{bmatrix}
#     f_1 & f_{H+1} & f_{2H+1} & \dots  & f_{HL-L+1} \\
#     f_2 & f_{H+2} & f_{2H+2} & \dots  & f_{HL-L+2} \\
#     \vdots & \vdots & \vdots & \ddots & \vdots \\
#     f_H &  f_{2H} & f_{3H} & \dots  & f_{HL}
# \end{bmatrix} =>
# f =
# \begin{bmatrix}
# f_1 \\
# f_2 \\
# \vdots \\
# f_{HL}
# \end{bmatrix}
# $
#
# This is then consistent with how reshape works in julia (and in MATLAB)

# %%
A = [1 2 3;4 5 6;7 8 9]
# Out:
# 3×3 Array{Int64,2}:
#  1  2  3
#  4  5  6
#  7  8  9

# %%
A_Vec = reshape(A,(1,9))
# Out:
# 1×9 Array{Int64,2}:
#  1  4  7  2  5  8  3  6  9

# %% [markdown]
# This is nice because when we solve for $f$, we can `reshape` to get back to the proper 2D matrix again

# %%
reshape(A_Vec,(3,3))
# Out:
# 3×3 Array{Int64,2}:
#  1  2  3
#  4  5  6
#  7  8  9

# %% [markdown]
# So now, in the x derivative matrix, $\textbf{D}_x^{(2)}$, we will have entries that are indicitive of the boundary condition. When we want the x partial derivative at the point on the left edge, we need to make an assumption about the point to the left and vice versa for the right edge. Due to the way we formed $f$, that means the point in $\textbf{D}_x^{(2)}$ at $(L,L+1)$ and $(L+1,L)$ control the boundary conditions. **However**, if we but a value in that location, that would get multiplied by the next term in $f$, which is not the desired outcome. Therefore, we have to but 0 there to *disconnect* those rows in 2D and apply the boundary conditions to b.
#
# Formulating $\textbf{D}_y^{(2)}$ is very similar, where we have to account for where y connects in $f$. Because the next Y term is $L$ away from $f_k$, we have to place the 1s for the $y_{j-1}$ entry at the $\pm H$ diagonals.
#
# Finally, as before, our problem statement is $-\frac{\varphi(x_{i-1},y_j) - 2\varphi(x_i,y_j) + \varphi(x_{i+1},y_j)}{\Delta x^2}-\frac{\varphi(x_{i},y_{j-1}) - 2\varphi(x_i,y_j) + \varphi(x_i,y_{j+1})}{\Delta y^2} = s(x_i,y_j)$
#
# We can rewrite this as matricies with $-\frac{1}{\Delta_x^2}\textbf{D}_x^{(2)}f-\frac{1}{\Delta_y^2}\textbf{D}_y^{(2)}f = s(x,y)$, simplifying the equation: $f(-\frac{1}{\Delta_x^2}\textbf{D}_x^{(2)}-\frac{1}{\Delta_y^2}\textbf{D}_y^{(2)}) = s(x,y)$
#
# The subtraction turns the $\textbf{D}$ matricies into an $\textbf{A}$ matrix, and our problem is $\textbf{A}x = b$

# %%
# I'd rather pass in numpoints as a tuple so I can support non-square problem spaces
function poisson_2d_dirichlet(source::Function,dirichlet::Function,
                              L::Number,H::Number,numPoints::Tuple{Integer,Integer})
    # numPoints[1] is the "L" from my formulation
    Δx = L/numPoints[1] # Physical resolutions
    Δy = H/numPoints[2]
    
    # We are only solving the inner matrix, the outer edge is defined with the boundary condition
    problemSpace = (numPoints[1])*(numPoints[2])
    
    # Form the diagonals
    mainDiagonal = 0 => fill(-2,problemSpace)
    topDiagonal =  1 => fill(1,problemSpace-1)
    botDiagonal = -1 => fill(1,problemSpace-1)
    D_x = spdiagm(mainDiagonal,topDiagonal,botDiagonal)
    # Now place the zeros in the off-diagonals
    for i = numPoints[1]:numPoints[1]:problemSpace-1
        D_x[i,i+1] = 0
        D_x[i+1,i] = 0
    end
    # And fix the sparse matrix to clean the zeros
    dropzeros!(D_x)
    
    # Now to formulate D_y
    topDiagonal =  numPoints[1] => fill(1,problemSpace-(numPoints[2]))
    botDiagonal = -(numPoints[1]) => fill(1,problemSpace-(numPoints[2]))
    D_y = spdiagm(mainDiagonal,topDiagonal,botDiagonal)
    
    # Now make A
    A = (-(1/Δx^2).*D_x -(1/Δy^2).*D_y)
    
    # Now generate the source vector in 2D
    s = [source(x,y,numPoints[1],numPoints[2]) for x = 1:numPoints[1], y = 1:numPoints[2]]
    b = copy(s)
    
    # Apply the boundary conditions
    for j=1:numPoints[1]
        if j == 1
            # Top left
            b[1,j] = b[1,j] + dirichlet(2,1,numPoints[1],numPoints[2])/Δy^2 + dirichlet(1,2,numPoints[1],numPoints[2])/Δx^2
            # Bottom Left
            b[end,j] = b[end,j] + dirichlet(2,numPoints[2]+2,numPoints[1],numPoints[2])/Δy^2 + dirichlet(1,numPoints[2]+1,numPoints[1],numPoints[2])/Δx^2    
        elseif j == numPoints[2]
            # Top Right
            b[1,j] = b[1,j] + dirichlet(numPoints[1]+1,1,numPoints[1],numPoints[2])/Δy^2 + dirichlet(numPoints[1]+2,2,numPoints[1],numPoints[2])/Δx^2
            # Bottom Right
            b[end,j] = b[end,j] + dirichlet(numPoints[1]+1,numPoints[2]+2,numPoints[1],numPoints[2])/Δy^2 + dirichlet(numPoints[1]+2,numPoints[2]+1,numPoints[1],numPoints[2])/Δx^2
        else
            # Top Edge
            b[1,j] = b[1,j] + dirichlet(j+1,1,numPoints[1],numPoints[2])/Δy^2
            
            # Bottom Edge
            b[end,j] = b[end,j] + dirichlet(j+1,numPoints[2]+2,numPoints[1],numPoints[2])/Δy^2
        end
    end
    
    # Now for left and right edge
    for i=2:numPoints[2]-1
        # Left Edge
        b[i,1] = b[i,1] + dirichlet(1,i+1,numPoints[1],numPoints[2])/Δx^2
        # Right Edge
        b[i,end] = b[i,end] + dirichlet(numPoints[1]+2,i+1,numPoints[1],numPoints[2])/Δx^2
    end
    
    # Reshape to 1D
    b = reshape(b,problemSpace)
    
    # Solve and benchmark
    f,time,bytes = @timed A\b
        
    # Solve
    return reshape(f,(numPoints[1],numPoints[2])) , s, time, bytes
end
# Out:
# poisson_2d_dirichlet (generic function with 1 method)

# %% [markdown]
# Now we write some functions that describe the source

# %%
# Zero Source
function zero_s(args...)
    return 0.
end

# Uniform Source
function uniform_s(args...)
    return 1.
end

# Linear Source
function linear_s(args...)
    return args[1]/args[3] # x/L
end

# Linear Source in x and y
function linear_xy_s(args...)
    return args[1]/args[3] + (2*args[2])/args[4]
end

# Non Linear
function nonlinear_s(args...)
    return 50*((args[1]/args[3])^2 + sin(10*args[2]/args[4]))
end
# Out:
# nonlinear_s (generic function with 1 method)

# %% [markdown]
# Now we will write some dirichlet conditions with signature x,y,L,H

# %%
function homogeneous(args...)
    return 0.
end

function non_homogeneous(args...)
    return 1.
end

function homogeneous_x(args...)
    # This is not the best way to so this but lol whatever
    A = zeros(Float64,(args[4]+2,args[3]+2))
    A[2:end-1,1] = fill(1.,args[3])
    A[2:end-1,end] = fill(1.,args[3])
    return A[args[2],args[1]]
end

function linear_x(args...)
    # This is not the best way to so this but lol whatever
    A = zeros(Float64,(args[4]+2,args[3]+2))
    A[2:end-1,1] = [x/args[3] for x = 1:args[3]]
    A[2:end-1,end] = [x/args[3] for x = 1:args[3]]
    return A[args[2],args[1]]
end

function square_x(args...)
    # This is not the best way to so this but lol whatever
    A = zeros(Float64,(args[4]+2,args[3]+2))
    A[2:end-1,1] = [(x/args[3])^2 for x = 1:args[3]]
    A[2:end-1,end] = [(x/args[3])^2 for x = 1:args[3]]
    return A[args[2],args[1]]
end
# Out:
# square_x (generic function with 1 method)

# %% [markdown]
# ## Sanity Check - Zero Source, Zero Boundaries

# %%
L = 1; H = 1; x_size = 100; y_size = 100
f,s = poisson_2d_dirichlet(zero_s,homogeneous,L,H,(x_size,y_size))
p1 = heatmap(f,aspect_ratio=:equal,title="Result")
p2 = heatmap(s,aspect_ratio=:equal,title="Source")
plot(p1,p2,layout=2)

# %% [markdown]
# Looks good, uniform zeros. Now to check with some BCs.
#
# If we puts ones on the edges with a unifrom excitation
#
# ## Uniform with Ones on Boundaries

# %%
f,s = poisson_2d_dirichlet(uniform_s,non_homogeneous,L,H,(x_size,y_size))
p1 = heatmap(f,aspect_ratio=:equal,title="Result")
p2 = heatmap(s,aspect_ratio=:equal,title="Source")
plot(p1,p2,layout=2)

# %% [markdown]
# ## Uniform with Ones on Left and Right Edge

# %%
f,s = poisson_2d_dirichlet(uniform_s,homogeneous_x,L,H,(x_size,y_size))
p1 = heatmap(f,aspect_ratio=:equal,title="Result")
p2 = heatmap(s,aspect_ratio=:equal,title="Source")
plot(p1,p2,layout=2)

# %% [markdown]
# Perfect, the solution has ones on the entire left edge and zeros on the top and bottom
#
# ## Uniform with Linear BC on Left and Right Edge

# %%
f,s = poisson_2d_dirichlet(uniform_s,linear_x,L,H,(x_size,y_size))
p1 = heatmap(f,aspect_ratio=:equal,title="Result")
p2 = heatmap(s,aspect_ratio=:equal,title="Source")
plot(p1,p2,layout=2)

# %% [markdown]
# ## Linear Excitation with Linear BC

# %%
f,s = poisson_2d_dirichlet(linear_s,linear_x,L,H,(x_size,y_size))
p1 = heatmap(f,aspect_ratio=:equal,title="Result")
p2 = heatmap(s,aspect_ratio=:equal,title="Source")
plot(p1,p2,layout=2)

# %% [markdown]
# Last but not least
#
# ## Non-Linear with Exponential BC

# %%
f,s = poisson_2d_dirichlet(nonlinear_s,square_x,L,H,(x_size,y_size))
p1 = heatmap(f,aspect_ratio=:equal,title="Result")
p2 = heatmap(s,aspect_ratio=:equal,title="Source")
plot(p1,p2,layout=2)

# %% [markdown]
# ## Mesh Refinement
#
# So to check for convergance, we will have some "tolerance" of 1e-3. We will start with some initial grid size and interpolate betwen iterations and compare the max of the difference. We will continue increasing grid size until we are beneath the convergance.

# %%
function solvePoissonWithConvergance(source::Function,dirichlet::Function,L::Number,H::Number,tolerance::Float64)
    gridSizes = [10,20] # Initial Grid Sizes, we are going to roll with square
    results = []
    f1 = poisson_2d_dirichlet(source,dirichlet,L,H,(gridSizes[1],gridSizes[1]))[1]
    lastF = poisson_2d_dirichlet(source,dirichlet,L,H,(gridSizes[2],gridSizes[2]))[1]
    # Interpolate and compare
    itp = interpolate(f1,BSpline(Constant())) # Nearest Neighbor
    f_range = range(1,stop=gridSizes[1],length=gridSizes[2])
    f1_scaled = [itp(x,y) for x = f_range, y = f_range]
    append!(results,maximum(abs.(lastF-f1_scaled)))
    
    # Iterate
    while results[end] >= tolerance
        append!(gridSizes,gridSizes[end]+1) ## Double the grid size
        f = poisson_2d_dirichlet(source,dirichlet,L,H,(gridSizes[end],gridSizes[end]))[1]
        # Interpolate and compare
        itp = interpolate(lastF,BSpline(Constant())) # Nearest Neighbor
        f_range = range(1,stop=gridSizes[end-1],length=gridSizes[end])
        f_scaled = [itp(x,y) for x = f_range, y = f_range]
        append!(results,maximum(abs.(f-f_scaled)))
        lastF = copy(f)
    end
    
    # Return results
    return f1,lastF,gridSizes[2:end],results
end
# Out:
# solvePoissonWithConvergance (generic function with 1 method)

# %%
f1,f,sizes,convergance = solvePoissonWithConvergance(uniform_s,homogeneous,L,H,0.1e-3)
p2 = plot(sizes,convergance,title="Convergance vs Grid Size")
p1 = heatmap(f,aspect_ratio=:equal,title="Result")
p0 = heatmap(f1,aspect_ratio=:equal,title="Before Mesh Refinement")
plot(p0,p1,p2,layout=3)

# %% [markdown]
# ## Profile Information
# Lets profile the solver as a function of grid size.

# %%
gridSizes = 1:10:500
memory = zeros(length(gridSizes))
times = zeros(length(gridSizes))
for (i,dim) in enumerate(gridSizes)
    f,s,t,b = poisson_2d_dirichlet(nonlinear_s,square_x,L,H,(dim,dim))
    memory[i] = (b/1024)/1024
    times[i] = t/1e-3
end
plot(gridSizes,times,ylabel="Time (ms)",xlabel="Grid Size",title="Time Complexity")

# %%
plot(gridSizes,memory,ylabel="Memory (MiB)",xlabel="Grid Size",title="Time Complexity")

# %% [markdown]
# And just to compare the entire function with the multi-sample benchmarking tool

# %%
@benchmark poisson_2d_dirichlet(nonlinear_s,square_x,L,H,(500,500))
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  4.15 GiB
#   allocs estimate:  28165
#   --------------
#   minimum time:     1.981 s (27.47% GC)
#   median time:      2.059 s (30.66% GC)
#   mean time:        2.054 s (29.60% GC)
#   maximum time:     2.123 s (30.56% GC)
#   --------------
#   samples:          3
#   evals/sample:     1

# %% [markdown]
# So there is a *LOT* of overhead in my function. If I cared more I would profile it and try to minimize all the unnecessary copying and such I am doing.
